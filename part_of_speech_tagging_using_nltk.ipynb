# %%
f = open('/content/drive/My Drive/my_nlp/sample_text.txt', 'r')
text = f.read()

# %%
# Out:
# 'Knowing how to write a paragraph is incredibly important. It is a basic aspect of writing, and it is something that everyone should know how to do. There is a specific structure that you have to follow when you are writing a paragraph. This structure helps make it easier for the reader to understand what is going on. Through writing good paragraphs, a person can communicate a lot better through their writing. When you want to write a paragraph, most of the time you should start off by coming up with an idea. After you have your idea or topic, you can start thinking about different things you can do to expand upon that idea. You should only finish the paragraph when you have finished covering everything you want about that idea.\n\n\n\n'

# %%
from nltk import word_tokenize, pos_tag, download
download('punkt') # to use word_tokenize()
download('averaged_perceptron_tagger') # to use pos_tag()
words = word_tokenize(text)
pos_tag(words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('Knowing', 'VBG'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('write', 'VB'),
#  ('a', 'DT'),
#  ('paragraph', 'NN'),
#  ('is', 'VBZ'),
#  ('incredibly', 'RB'),
#  ('important', 'JJ'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('basic', 'JJ'),
#  ('aspect', 'NN'),
#  ('of', 'IN'),
#  ('writing', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('something', 'NN'),
#  ('that', 'IN'),
#  ('everyone', 'NN'),
#  ('should', 'MD'),
#  ('know', 'VB'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('specific', 'JJ'),
#  ('structure', 'NN'),
#  ('that', 'IN'),
#  ('you', 'PRP'),
# ...

# %%
sentence = 'I want to learn NLP'
words = word_tokenize(sentence)
pos_tag(words)
# Out:
# [('I', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('learn', 'VB'), ('NLP', 'NNP')]
